# %% [markdown]
# <a href="https://colab.research.google.com/github/engrayubhassan266-afk/machine-learning-first-project-of-model-training/blob/main/multi_linear_regresion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/drive/MyDrive/vehicle_price_data.csv")
df
plt.scatter(df.year,df.price)
#plt.scatter(df.year,df.cylinder,df.mileage,df.price)
plt.xlabel("year",color='red')
plt.ylabel("price",color='red')
plt.title("year vs price",color='green')

# Sort the DataFrame by 'year' to plot a smooth regression line
df_sorted = df.sort_values(by='year')
# Plot the regression line using 'year' and predicting with all trained features
plt.plot(df_sorted.year, lr.predict(df_sorted[['year','cylinder','mileage']]), color="red")

plt.show()

# %%
lr=linear_model.LinearRegression()
lr.fit(df[['year','cylinder','mileage']],df.price)
# Out:
# LinearRegression()

# %%
lr.predict([[2022,8,23000]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([31994.41941757])

# %%
lr.score(df[['year','cylinder','mileage']],df.price)
# Out:
# 0.9956145552947471

# %%
lr.coef_
# Out:
# array([ 4.78450884e+03, -3.65897936e+02,  1.68627715e-01])

# %%
lr.intercept_
# Out:
# np.float64(-9643233.712096613)

# %%
price=4.78450884e+03*2022 + -3.65897936e+02*8+1.68627715e-01*23000+-9643233.712096613
price
# Out:
# 31994.416340388358
